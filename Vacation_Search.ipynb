# %%
####### PART 2. GET THE WEATHER DESCRIPCION AND AMOUNT OF PRECIPITATION 
####### FOR EACH CITY

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import gmaps
import requests
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/weatherpy_challenge.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date    Lat     Lng  \
# 0        0    Punta Arenas      CL  2019-11-12 05:34:58 -53.16  -70.91
# 1        1  Guerrero Negro      MX  2019-11-12 05:34:59  27.97 -114.04
# 2        2         Saurimo      AO  2019-11-12 05:34:59  -9.66   20.40
# 3        3       Saskylakh      RU  2019-11-12 05:34:59  71.97  114.09
# 4        4          Cancun      MX  2019-11-12 05:33:28  21.17  -86.85
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 0     39.20        93          88        5.82     overcast clouds
# 1     62.02        91           0        7.65           clear sky
# 2     68.50        92          62        5.14          light rain
# 3    -17.99        95          44        7.58    scattered clouds
# 4     77.00       100          75       11.41       broken clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      0.00                       0.0
# ...

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
rain_desc = str(input("Do you want it to be raining? (yes/no)"))
snow_desc = str(input("Do you want it to be snowing (yes/no)"))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 90
# Do you want it to be raining? (yes/no)yes
# Do you want it to be snowing (yes/no)yes

# %%
print (min_temp, max_temp, rain_desc, snow_desc)
# Out:
# 60.0 90.0 yes yes

# %%
if rain_desc == 'yes' and snow_desc == 'yes':
    
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] > 0) | (city_data_df["Snow inches (last 3 hrs)"])>0]

elif rain_desc == 'yes' and snow_desc == 'no':
    
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"] > 0) & (city_data_df["Snow inches (last 3 hrs)"])==0]

elif rain_desc == 'no' and snow_desc == 'yes':
    
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"]==0) & (city_data_df["Snow inches (last 3 hrs)"]>0)]

else:
    preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp) & (city_data_df["Rain inches (last 3 hrs)"]==0) & (city_data_df["Snow inches (last 3 hrs)"]==0)]    

preferred_cities_df.head(10)
# Out:
#     City_ID           City Country                 Date    Lat     Lng  \
# 2         2        Saurimo      AO  2019-11-12 05:34:59  -9.66   20.40
# 6         6  Cockburn Town      TC  2019-11-12 05:32:56  21.46  -71.14
# 13       13       Hermanus      ZA  2019-11-12 05:35:01 -34.42   19.24
# 16       16        Bertoua      CM  2019-11-12 05:35:02   4.58   13.68
# 22       22        Rikitea      PF  2019-11-12 05:35:03 -23.12 -134.97
# 29       29     Bredasdorp      ZA  2019-11-12 05:35:05 -34.53   20.04
# 37       37       Khatanga      RU  2019-11-12 05:35:07  71.98  102.47
# 42       42       Cidreira      BR  2019-11-12 05:35:08 -30.17  -50.22
# 57       57       Qaqortoq      GL  2019-11-12 05:35:11  60.72  -46.03
# 64       64     Cape Coast      GH  2019-11-12 05:35:13   5.11   -1.24
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# 2      68.50        92          62        5.14          light rain
# ...

# %%
# Filter the dataset to find the cities that fit the criteria.
#preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
#                                      (city_data_df["Max Temp"] >= min_temp) & \
#                                       (city_data_df["Rain inches (last 3 hrs)"]) & \ 
#                                       (city_data_df["Snow inches (last 3 hrs)"])]
#preferred_cities_df.head(10)

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp","Current Description", "Lat", "Lng","Rain inches (last 3 hrs)","Snow inches (last 3 hrs)"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description    Lat     Lng  \
# 2         Saurimo      AO     68.50          light rain  -9.66   20.40
# 6   Cockburn Town      TC     81.61          light rain  21.46  -71.14
# 13       Hermanus      ZA     64.00          light rain -34.42   19.24
# 16        Bertoua      CM     71.49          light rain   4.58   13.68
# 22        Rikitea      PF     70.50       moderate rain -23.12 -134.97
# 29     Bredasdorp      ZA     62.60       moderate rain -34.53   20.04
# 37       Khatanga      RU     -5.91          light snow  71.98  102.47
# 42       Cidreira      BR     69.10          light rain -30.17  -50.22
# 57       Qaqortoq      GL     30.20                snow  60.72  -46.03
# 64     Cape Coast      GH     81.32          light rain   5.11   -1.24
#
#     Rain inches (last 3 hrs)  Snow inches (last 3 hrs) Hotel Name
# 2                       0.31                      0.00
# 6                       0.31                      0.00
# ...

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    
    # Grab the first hotel from the results and store the name.
    try:
        # Get the latitude and longitude.
        lat = row["Lat"]
        lng = row["Lng"]

        # Add the latitude and longitude to the params dictionary as values to
        # the location key.
        params["location"] = f"{lat},{lng}"

        # Use the search term: "lodging" and our latitude and longitude.
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
        # Make request and get the JSON data from the search.
        hotels = requests.get(base_url, params=params).json()
        # Grab the first hotel from the results and store the name.
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# ...

# %%
hotel_df
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 2          Saurimo      AO     68.50          light rain  -9.66   20.40
# 6    Cockburn Town      TC     81.61          light rain  21.46  -71.14
# 13        Hermanus      ZA     64.00          light rain -34.42   19.24
# 16         Bertoua      CM     71.49          light rain   4.58   13.68
# 22         Rikitea      PF     70.50       moderate rain -23.12 -134.97
# ..             ...     ...       ...                 ...    ...     ...
# 554      Tilichiki      RU     27.46          light snow  60.47  166.10
# 557          Wagar      US     66.00          light rain  31.44  -87.99
# 562      Mossendjo      CG     72.37          light rain  -2.95   12.72
# 564    Pyaozerskiy      RU     26.13          light snow  65.83   31.17
# 567          Kapit      MY     81.90          light rain   2.02  112.94
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs) Hotel Name
# ...

# %%
# Heatmap of temperature
#city_data_df_temp_df= city_data_df[city_data_df['Max Temp']>= 0]

# %%
#hotel_df=hotel_df.drop(hotel_df[hotel_df['Max Temp']<0].index,inplace=True)

# %%
new_hotel_df=hotel_df.loc[hotel_df['Max Temp']>=0]
new_hotel_df
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 2          Saurimo      AO     68.50          light rain  -9.66   20.40
# 6    Cockburn Town      TC     81.61          light rain  21.46  -71.14
# 13        Hermanus      ZA     64.00          light rain -34.42   19.24
# 16         Bertoua      CM     71.49          light rain   4.58   13.68
# 22         Rikitea      PF     70.50       moderate rain -23.12 -134.97
# ..             ...     ...       ...                 ...    ...     ...
# 554      Tilichiki      RU     27.46          light snow  60.47  166.10
# 557          Wagar      US     66.00          light rain  31.44  -87.99
# 562      Mossendjo      CG     72.37          light rain  -2.95   12.72
# 564    Pyaozerskiy      RU     26.13          light snow  65.83   31.17
# 567          Kapit      MY     81.90          light rain   2.02  112.94
#
#      Rain inches (last 3 hrs)  Snow inches (last 3 hrs) Hotel Name
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/weatherpy_vacation.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in new_hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = new_hotel_df[["Lat", "Lng"]]
max_temp = new_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
#            max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
